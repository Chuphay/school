# %%
# %load_ext rpy2.ipython

# %%
# %%R
# m <- 1000
# x <- runif(m)
# y <- runif(m)
# plot(x,y)
# z <- seq(0,1,by = 0.1)
# lines(z,dnorm(z))
# mean(y<dnorm(x))
# Out:
# [1] 0.336

# %%
# %%R
# m <-10000
# z <- rnorm(m)
# mean(z>0 & z<1)
# Out:
# [1] 0.3355

# %%
# %%R
# m <- 10000
# u <- runif(m)
# x <- dnorm(u)
# sum(x/m)
# Out:
# [1] 0.3410213
