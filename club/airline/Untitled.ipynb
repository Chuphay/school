# %%
f = open("sample.csv")

# %%
for line in f.readlines():
    print("<tr>")
    for el in line.split(","):
        print("<td>"+el+"</td>")
    print("</tr>")
# Out:
# <tr>
# <td>Year</td>
# <td>Month</td>
# <td>DayofMonth</td>
# <td>DayOfWeek</td>
# <td>DepTime</td>
# <td>CRSDepTime</td>
# <td>ArrTime</td>
# <td>CRSArrTime</td>
# <td>UniqueCarrier</td>
# <td>FlightNum</td>
# <td>TailNum</td>
# <td>ActualElapsedTime</td>
# <td>CRSElapsedTime</td>
# <td>AirTime</td>
# <td>ArrDelay</td>
# <td>DepDelay</td>
# <td>Origin</td>
# <td>Dest</td>
# <td>Distance</td>
# <td>TaxiIn</td>
# <td>TaxiOut</td>
# <td>Cancelled</td>
# <td>CancellationCode</td>
# <td>Diverted</td>
# <td>CarrierDelay</td>
# <td>WeatherDelay</td>
# <td>NASDelay</td>
# <td>SecurityDelay</td>
# <td>LateAircraftDelay
# </td>
# </tr>
# <tr>
# <td>1989</td>
# <td>1</td>
# <td>23</td>
# <td>1</td>
# <td>1419</td>
# <td>1230</td>
# <td>1742</td>
# <td>1552</td>
# <td>UA</td>
# <td>183</td>
# <td>NA</td>
# <td>323</td>
# <td>322</td>
# <td>NA</td>
# <td>110</td>
# <td>109</td>
# <td>SFO</td>
# <td>HNL</td>
# <td>2398</td>
# <td>NA</td>
# <td>NA</td>
# <td>0</td>
# <td>NA</td>
# <td>0</td>
# ...
