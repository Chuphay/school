# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
a = diag(ones(19),1)
a = a + a.T
la = diag(a.sum(axis = 1)) - a
[v,d] = eig(la);
v,d = zip(*sorted(zip(v,d)))
#print([round(i,5) for i in v])
#print(sorted(asarray(d)[:,0]))
plot(sorted(asarray(d)[:,0]));

# %%
for i in range(18,20):
    plot(sorted(asarray(d)[:,i]));
#plot((asarray(d)[:,3]));

# %%
# %load_ext oct2py.ipython

# %%
# %%octave
# a = diag(ones(1,19),1);
# a = a + a';
# la = diag(sum(a)) - a;
# [v,d] = eig(full(la));
# diag(d)
# plot(v(:,2));
# hold on; plot(v(:,2),'o');
# Out:
# ans =
#
#   0.00000
#   0.02462
#   0.09789
#   0.21799
#   0.38197
#   0.58579
#   0.82443
#   1.09202
#   1.38197
#   1.68713
#   2.00000
#   2.31287
#   2.61803
#   2.90798
#   3.17557
#   3.41421
#   3.61803
#   3.78201
#   3.90211
#   3.97538

# %%
# %%octave
# plot(v(:,2));
# hold on; plot(v(:,2),'o');
# plot(v(:,3),'k');
# plot(v(:,3),'ko');
# plot(v(:,4),'r');
# plot(v(:,4),'ro');

# %%
# %%octave
# v(:,2)
# d
# Out:
# ans =
#
#   -0.31525
#   -0.30749
#   -0.29216
#   -0.26963
#   -0.24046
#   -0.20537
#   -0.16523
#   -0.12102
#   -0.07382
#   -0.02481
#   0.02481
#   0.07382
#   0.12102
#   0.16523
#   0.20537
#   0.24046
#   0.26963
#   0.29216
#   0.30749
#   0.31525
#
# d =
#
# Diagonal Matrix
#
#  Columns 1 through 8:
#
#   0.00000        0        0        0        0        0        0        0
#         0  0.02462        0        0        0        0        0        0
#         0        0  0.09789        0        0        0        0        0
#         0        0        0  0.21799        0        0        0        0
#         0        0        0        0  0.38197        0        0        0
#         0        0        0        0        0  0.58579        0        0
#         0        0        0        0        0        0  0.82443        0
#         0        0        0        0        0        0        0  1.09202
#         0        0        0        0        0        0        0        0
# ...

# %%
d,v  = eig(la);

# %%
d, v = zip(*sorted(zip(d, v.T)))
d
# Out:
# (-4.691879127057819e-17,
#  0.024623318809724477,
#  0.097886967409692938,
#  0.21798695162326426,
#  0.38196601125010515,
#  0.58578643762690497,
#  0.8244294954150535,
#  1.0920190005209065,
#  1.381966011250106,
#  1.6871310699195392,
#  1.9999999999999998,
#  2.3128689300804628,
#  2.6180339887498958,
#  2.9079809994790931,
#  3.1755705045849454,
#  3.414213562373094,
#  3.618033988749894,
#  3.7820130483767369,
#  3.9021130325903073,
#  3.9753766811902747)

# %%
sorted(v[1])
# Out:
# [-0.31525294134988857,
#  -0.30749036766932675,
#  -0.29215636063472344,
#  -0.2696284943899227,
#  -0.24046147976757279,
#  -0.20537350546744801,
#  -0.16522855386712756,
#  -0.121015126908467,
#  -0.073821905899139895,
#  -0.024810944565716791,
#  0.024810944565718314,
#  0.073821905899141546,
#  0.12101512690846886,
#  0.16522855386712984,
#  0.20537350546745053,
#  0.24046147976757559,
#  0.26962849438992537,
#  0.29215636063472611,
#  0.30749036766932908,
#  0.31525294134989079]

# %%
plot((v[1]))

# %%
# %%octave
# v(:,3)
# Out:
# ans =
#
#   0.31233
#   0.28176
#   0.22361
#   0.14356
#   0.04947
#   -0.04947
#   -0.14356
#   -0.22361
#   -0.28176
#   -0.31233
#   -0.31233
#   -0.28176
#   -0.22361
#   -0.14356
#   -0.04947
#   0.04947
#   0.14356
#   0.22361
#   0.28176
#   0.31233

# %%
plot(v[1])
plot(v[2])
plot(v[3])
